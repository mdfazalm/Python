# %% [markdown]
# <a href="https://colab.research.google.com/github/mdfazalm/Python/blob/main/FOODAPP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
fa=pd.read_csv(r"C:\Users\Administrator\Desktop\Python\FOODAPP.csv")

# %%
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 1286  https://www.zomato.com/bangalore/cafe-arabica-...
# 1287  https://www.zomato.com/bangalore/pizza-on-the-...
# 1288  https://www.zomato.com/bangalore/smoor-bannerg...
# 1289  https://www.zomato.com/bangalore/kafe-nook-btm...
# 1290  https://www.zomato.com/bangalore/kumbha-bhojan...
#
#                                                 address  \
# 0     942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...
# 1     2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...
# 2     1112/ Next to KIMS Medical College/ 17th Cross...
# 3     1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...
# ...

# %%
A=fa[(fa["approx_cost_for_two_people"]>=800)&(fa["location"]=="Bannerghatta Road")]

# %%
A[["name", "rest_type"]]
# Out:
#                                 name            rest_type
# 730                           Tulips        Casual Dining
# 750                  Cafe Coffee Day                 Cafe
# 752                            Smoor       Dessert Parlor
# 754                    Shee-Sha Cafe  Cafe/ Casual Dining
# 881        Rajdhani Thali Restaurant        Casual Dining
# 889   Savoury - Sea Shell Restaurant        Casual Dining
# 893                          Kundana        Casual Dining
# 917                        Chung Wah        Casual Dining
# 984                  Nellore Ruchulu        Casual Dining
# 1011                   Simply Indian        Casual Dining
# 1017                 Cafe Coffee Day                 Cafe
# 1026                 Ambara Gardenia        Casual Dining
# 1106    Street Foods by Punjab Grill           Food Court
# 1125                         Intalia           Food Court
# 1153                  Pika's Kitchen        Casual Dining
# ...

# %%
B.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                          float64
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# cuisines                       object
# approx_cost_for_two_people      int64
# reviews_list                   object
# menu_item                      object
# listed_in_type                 object
# listed_in_city                 object
# payMode                        object
# Discount                        int64
# Capacity                        int64
# Catering                       object
# dtype: object

# %%
B=fa[(fa["approx_cost_for_two_people"]<=800)&(fa["approx_cost_for_two_people"]>=500)&(fa["location"]=="Bannerghatta Road")]

# %%
B[["name","location","rest_type"]]
# Out:
#                             name           location      rest_type
# 728            Empire Restaurant  Bannerghatta Road  Casual Dining
# 729              Abhiruchi Hotel  Bannerghatta Road  Casual Dining
# 730                       Tulips  Bannerghatta Road  Casual Dining
# 742                  Tisano Cafe  Bannerghatta Road           Cafe
# 743                  Cafe Kabana  Bannerghatta Road           Cafe
# ...                          ...                ...            ...
# 1269                 Guru Greens  Bannerghatta Road  Casual Dining
# 1272  Delifusion - Hunger Sorted  Bannerghatta Road    Quick Bites
# 1281                 Eagle Ridge  Bannerghatta Road  Casual Dining
# 1285           Punjabi Unplugged  Bannerghatta Road    Quick Bites
# 1286                Cafe Arabica  Bannerghatta Road   Cafe/ Bakery
#
# [78 rows x 3 columns]

# %%
#TOP VOTED RESTAURANT DETAILS

# %%
C=fa[(fa["menu_item"]!="notAvailable")&(fa["votes"]>500)]

# %%
C[["name","rest_type"]]
# Out:
#                                              name           rest_type
# 42                                         Recipe       Casual Dining
# 50                                      FreshMenu            Delivery
# 68    Sri Guru Kottureshwara Davangere Benne Dosa         Quick Bites
# 111                                  Anna Kuteera       Casual Dining
# 247                              Kamat Bugle Rock         Quick Bites
# 349                                        Maiyas         Quick Bites
# 412                               Ayodhya Upachar         Quick Bites
# 417                             The Krishna Grand       Casual Dining
# 419                                     Roti Ghar       Casual Dining
# 476                             The Krishna Grand       Casual Dining
# 486                                     Smacznego                Cafe
# 490                                  Anna Kuteera       Casual Dining
# ...

# %%
D=fa[(fa["votes"]>500)&(fa["rate"]>4.0)]

# %%
D.head()
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/smacznego-ban...
# 34  https://www.zomato.com/bangalore/szechuan-drag...
#
#                                               address             name  \
# 0   942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...            Jalsa
# 1   2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...   Spice Elephant
# 7   2469/ 3rd Floor/ 24th Cross/ Opposite BDA Comp...           Onesta
# 8   2470/ 21 Main Road/ 25th Cross/ Banashankari/ ...        Smacznego
# 34  8/ 2nd Floor/ 1st Main/ Arush Trapeze/ Mount J...  Szechuan Dragon
#
#    online_order book_table  rate  votes  \
# 0           Yes        Yes   4.1    775
# 1           Yes         No   4.1    787
# 7           Yes        Yes   4.6   2556
# 8           Yes         No   4.2    504
# ...

# %%
E=fa[(fa["votes"]>500)&(fa["rate"]>4.0)&fa['cuisines'].str.contains(r'\b' + "Continental"+ r'\b')]

# %%
E.head()
# Out:
#                                                    url  \
# 60   https://www.zomato.com/gustoesbeerhouse?contex...
# 401  https://www.zomato.com/bangalore/vinnys-banash...
# 481  https://www.zomato.com/bangalore/vinnys-banash...
# 483  https://www.zomato.com/gustoesbeerhouse?contex...
# 721  https://www.zomato.com/gustoesbeerhouse?contex...
#
#                                                address                name  \
# 60   10/ 30th Main/ Deve Gowda Petrol Bunk Road/ 3r...  Gustoes Beer House
# 401  2467/ 24th Cross/ 2nd Stage/ Banashankari/ Ban...             Vinny's
# 481  2467/ 24th Cross/ 2nd Stage/ Banashankari/ Ban...             Vinny's
# 483  10/ 30th Main/ Deve Gowda Petrol Bunk Road/ 3r...  Gustoes Beer House
# 721  10/ 30th Main/ Deve Gowda Petrol Bunk Road/ 3r...  Gustoes Beer House
#
#     online_order book_table  rate  votes         phone      location  \
# 60            No         No   4.1    868  080 49653521  Banashankari
# ...

# %%
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1286    False
# 1287    False
# 1288    False
# 1289    False
# 1290    False
# Name: cuisines, Length: 1291, dtype: bool

# %%
f=fa.sort_values(["rate"],ascending=0)
f
# Out:
#                                                    url  \
# 542  https://www.zomato.com/bangalore/taaza-thindi-...
# 731  https://www.zomato.com/bangalore/barbeque-nati...
# 479  https://www.zomato.com/bangalore/onesta-banash...
# 130  https://www.zomato.com/bangalore/the-blue-wago...
# 7    https://www.zomato.com/bangalore/onesta-banash...
# ..                                                 ...
# 981  https://www.zomato.com/bangalore/artinci-artis...
# 120  https://www.zomato.com/bangalore/bitez-banasha...
# 538  https://www.zomato.com/bangalore/parijatha-par...
# 995  https://www.zomato.com/bangalore/totus-btm-ban...
# 459  https://www.zomato.com/bangalore/gopi-ice-crea...
#
#                                                address  \
# 542  115/ 100 Feet Ring Road/ Kathriguppe/ Banashan...
# 731    67/ 15th Cross/ 6th B Main/ JP Nagar/ Bangalore
# 479  2469/ 3rd Floor/ 24th Cross/ Opposite BDA Comp...
# 130  615/1/ Ground Floor/ Janardhan Mansion/ 10th C...
# ...

# %%
g=f.sort_values(["votes"],ascending=0)
g.head()
# Out:
#                                                    url  \
# 77   https://www.zomato.com/bangalore/meghana-foods...
# 985  https://www.zomato.com/bangalore/brewsky-jp-na...
# 731  https://www.zomato.com/bangalore/barbeque-nati...
# 728  https://www.zomato.com/bangalore/empire-restau...
# 479  https://www.zomato.com/bangalore/onesta-banash...
#
#                                                address               name  \
# 77   52/ 1st Floor/ 33rd Cross/ 4th Block/ Jayanaga...      Meghana Foods
# 985  55/ 5th Floor/ Goenka Chambers/ 19th Main Road...            Brewsky
# 731    67/ 15th Cross/ 6th B Main/ JP Nagar/ Bangalore    Barbeque Nation
# 728  4 & 5/ Green Orchards Layout/ 1st Cross/ Banne...  Empire Restaurant
# 479  2469/ 3rd Floor/ 24th Cross/ Opposite BDA Comp...             Onesta
#
#     online_order book_table  rate  votes  \
# 77           Yes         No   4.4   4401
# 985          Yes        Yes   4.4   4309
# 731           No        Yes   4.7   3845
# ...

# %%
fa["reviews_list"]=fa["reviews_list"].replace(r'\b'"'/'"'\b',"")
fa
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 1286  https://www.zomato.com/bangalore/cafe-arabica-...
# 1287  https://www.zomato.com/bangalore/pizza-on-the-...
# 1288  https://www.zomato.com/bangalore/smoor-bannerg...
# 1289  https://www.zomato.com/bangalore/kafe-nook-btm...
# 1290  https://www.zomato.com/bangalore/kumbha-bhojan...
#
#                                                 address  \
# 0     942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...
# 1     2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...
# 2     1112/ Next to KIMS Medical College/ 17th Cross...
# 3     1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...
# ...

# %%
#top 5 with rate vote and appx cost for 2
a=fa.sort_values(["votes"],ascending=0)
b=a.sort_values(["rate"],ascending=0)
c=b.sort_values(["approx_cost_for_two_people"],ascending=0)
c[["name","location","cuisines","rate","votes","approx_cost_for_two_people","listed_in_type"]].head()
# Out:
#                      name      location                            cuisines  \
# 520  Ayda Persian Kitchen  Banashankari               North Indian/ Iranian
# 85   Ayda Persian Kitchen  Banashankari               North Indian/ Iranian
# 735          Mango Greens      JP Nagar  North Indian/ Continental/ Chinese
# 210       Cafe Coffee Day     Jayanagar                     Cafe/ Fast Food
# 499             Chung Wah  Banashankari    Chinese/ Momos/ Thai/ Vietnamese
#
#      rate  votes  approx_cost_for_two_people listed_in_type
# 520   3.7     39                         950       Dine-out
# 85    3.7     39                         950       Delivery
# 735   3.9     49                         900         Buffet
# 210   3.2     17                         900       Delivery
# 499   3.9    519                         900       Dine-out

# %%
a=fa["reviews_list"].split()[1]
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1596\2125851390.py in ?()
# ----> 1 a=fa["reviews_list"].split()[1]
#       2 a
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
x=fa.sort_values(["rate"],ascending=0)
y=x.sort_values(["votes"],ascending=0)
z=y[(y["rest_type"]=="Casual Dining")].head()

# %%
z
# Out:
#                                                    url  \
# 77   https://www.zomato.com/bangalore/meghana-foods...
# 731  https://www.zomato.com/bangalore/barbeque-nati...
# 728  https://www.zomato.com/bangalore/empire-restau...
# 935  https://www.zomato.com/bangalore/chulha-chauki...
# 172  https://www.zomato.com/bangalore/chutney-chang...
#
#                                                address  \
# 77   52/ 1st Floor/ 33rd Cross/ 4th Block/ Jayanaga...
# 731    67/ 15th Cross/ 6th B Main/ JP Nagar/ Bangalore
# 728  4 & 5/ Green Orchards Layout/ 1st Cross/ Banne...
# 935      13/ 7th Cross/ 2nd Phase/ JP Nagar/ Bangalore
# 172  Cosmopolitan Club/ 22nd Cross/ 3rd Block/ Jaya...
#
#                        name online_order book_table  rate  votes  \
# 77            Meghana Foods          Yes         No   4.4   4401
# 731         Barbeque Nation           No        Yes   4.7   3845
# 728       Empire Restaurant          Yes         No   4.3   3178
# ...

# %%
a=fa[(fa["Discount"]>30)]
x=a.sort_values(["rate"],ascending=0)
y=x.sort_values(["Discount"],ascending=0)
y[["name","location","rate","Discount"]]
# Out:
#                   name           location  rate  Discount
# 542       Taaza Thindi       Banashankari   4.7        50
# 1194    Northern Bites  Bannerghatta Road   3.3        50
# 742        Tisano Cafe  Bannerghatta Road   3.8        50
# 556   Utsav Restaurant       Banashankari   3.8        50
# 751       Cafe Arabica  Bannerghatta Road   3.8        50
# ...                ...                ...   ...       ...
# 910        Sagar Grand  Bannerghatta Road   3.8        35
# 201      Sri Udupi Veg          Jayanagar   3.3        35
# 1172       Chicken Man           JP Nagar   3.8        35
# 1159       Tisano Cafe  Bannerghatta Road   3.8        35
# 86        Chatar Patar       Banashankari   3.7        35
#
# [597 rows x 4 columns]

# %%
A=fa[(fa["Catering"]=="yes")&(fa["location"]=="Banashankari")]
A
# Out:
#                                                    url  \
# 0    https://www.zomato.com/bangalore/jalsa-banasha...
# 2    https://www.zomato.com/SanchurroBangalore?cont...
# 3    https://www.zomato.com/bangalore/addhuri-udupi...
# 9    https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11   https://www.zomato.com/bangalore/the-coffee-sh...
# ..                                                 ...
# 643  https://www.zomato.com/bangalore/bunts-biriyan...
# 644  https://www.zomato.com/bangalore/funjabi-curri...
# 722  https://www.zomato.com/bangalore/blue-wings-ba...
# 723  https://www.zomato.com/bangalore/vi-ras-bar-an...
# 724  https://www.zomato.com/bangalore/k27-the-pub-b...
#
#                                                address  \
# 0    942/ 21st Main Road/ 2nd Stage/ Banashankari/ ...
# 2    1112/ Next to KIMS Medical College/ 17th Cross...
# 3    1st Floor/ Annakuteera/ 3rd Stage/ Banashankar...
# 9    12/29 Near PES University Back Gate/ D'Souza N...
# ...

# %%
X=fa[(fa["rest_type"].str.contains("Cafe"))&(fa["payMode"].str.contains("CreditCard","Paytm"))]
X
# Out:
#                                                     url  \
# 9     https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 10    https://www.zomato.com/bangalore/cafe-shuffle-...
# 12    https://www.zomato.com/bangalore/caf-eleven-ba...
# 14    https://www.zomato.com/bangalore/cafe-vivacity...
# 15    https://www.zomato.com/bangalore/catch-up-ino-...
# ...                                                 ...
# 1209  https://www.zomato.com/bangalore/ruhs-cafe-btm...
# 1251  https://www.zomato.com/bangalore/willys-top-ca...
# 1259  https://www.zomato.com/bangalore/skytouch-le-c...
# 1266  https://www.zomato.com/bangalore/vaho-kafe-pre...
# 1270  https://www.zomato.com/bangalore/d-view-cafe-j...
#
#                                                 address  \
# 9     12/29 Near PES University Back Gate/ D'Souza N...
# 10    941/ 3rd FLOOR/ 21st Main/ 22nd Cross/ Banasha...
# 12    111/ Sapphire Toys Building/ 100 Feet Ring Roa...
# 14    2303/ 21st Cross/ K R Road/ 2nd Stage/ Banasha...
# ...

# %%
fa.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                          float64
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# cuisines                       object
# approx_cost_for_two_people      int64
# reviews_list                   object
# menu_item                      object
# listed_in_type                 object
# listed_in_city                 object
# payMode                        object
# Discount                        int64
# Capacity                        int64
# Catering                       object
# dtype: object

# %%
A=fa[(fa["rest_type"]=="Dessert Parlor")&(fa["Capacity"]>100)]
B=A.sort_values(["Capacity"],ascending=0)
C=B.sort_values(["rate"],ascending=0)
D=C.sort_values(["votes"],ascending=0)
D
# Out:
#                                                     url  \
# 183   https://www.zomato.com/bangalore/stoned-monkey...
# 438   https://www.zomato.com/bangalore/stoned-monkey...
# 121   https://www.zomato.com/bangalore/roll-over-jay...
# 1197  https://www.zomato.com/bangalore/natural-ice-c...
# 424   https://www.zomato.com/bangalore/corner-house-...
# 1138  https://www.zomato.com/bangalore/stoned-monkey...
# 1052  https://www.zomato.com/bangalore/rock-stone-ic...
# 432   https://www.zomato.com/bangalore/polar-bear-ba...
# 902   https://www.zomato.com/bangalore/cold-stone-cr...
# 1228  https://www.zomato.com/bangalore/berrylicious-...
# 87    https://www.zomato.com/bangalore/polar-bear-1-...
# 810   https://www.zomato.com/bangalore/cakebuy-banne...
# 458   https://www.zomato.com/bangalore/waffle-a-go-g...
# 429   https://www.zomato.com/bangalore/ammas-pastrie...
# 269   https://www.zomato.com/bangalore/chocoberry-ja...
# 239   https://www.zomato.com/bangalore/iceberg-icecr...
# ...

# %%
X=fa[(fa["Catering"]=="yes")&(fa["payMode"].str.contains(r'\b' + "Cash"+ r'\b'))&(fa["Discount"]>=50)&(fa["menu_item"]!="notAvailable")]
X
# Out:
#                                                     url  \
# 426   https://www.zomato.com/bangalore/xo-belgian-wa...
# 606   https://www.zomato.com/bangalore/tandoori-knig...
# 734   https://www.zomato.com/bangalore/zaitoon-jp-na...
# 744   https://www.zomato.com/bangalore/butterly-bann...
# 944   https://www.zomato.com/bangalore/basmati-delig...
# 954   https://www.zomato.com/bangalore/ahmeds-little...
# 959   https://www.zomato.com/bangalore/gowdru-mane-o...
# 1065  https://www.zomato.com/bangalore/the-food-cott...
#
#                                                 address                name  \
# 426   18/ B K Complex/ Opposite To BDA Complex/ 21st...   XO Belgian Waffle
# 606   34/ 22nd Main/ 22nd Cross/ Opposite BDA/ 2nd S...     Tandoori Knight
# 734   21/ 24th Main Road/ 6th Phase/ JP Nagar/ Banga...             Zaitoon
# 744   7/ Doddakammanahalli Main Road/ Central Excise...            Butterly
# 944   Shop 1/ 1st Floor/ BTM Complex/ 9th Main Road/...    Basmati Delights
# ...

# %%
Z=fa[(fa["online_order"]=="Yes")&(fa["book_table"]=="Yes")&(fa["payMode"].str.contains(r'\b' + "PhonePe"+ r'\b'))]
Z
# Out:
#                                                     url  \
# 7     https://www.zomato.com/bangalore/onesta-banash...
# 172   https://www.zomato.com/bangalore/chutney-chang...
# 188   https://www.zomato.com/bangalore/the-grillo-ja...
# 267   https://www.zomato.com/bangalore/the-royal-cor...
# 268   https://www.zomato.com/bangalore/hara-fine-din...
# 311   https://www.zomato.com/bangalore/desi-cream-ju...
# 345   https://www.zomato.com/bangalore/eurasia-pasta...
# 352   https://www.zomato.com/bangalore/jalpaan-jayan...
# 405   https://www.zomato.com/bangalore/andhra-ruchul...
# 489   https://www.zomato.com/bangalore/the-coffee-sh...
# 514   https://www.zomato.com/bangalore/my-tea-house-...
# 736   https://www.zomato.com/bangalore/oye-amritsar-...
# 737   https://www.zomato.com/bangalore/melt-eden-par...
# 856   https://www.zomato.com/bangalore/cheesiano-piz...
# 881   https://www.zomato.com/bangalore/rajdhani-thal...
# 915   https://www.zomato.com/bangalore/seasons-banne...
# ...

# %%
a=fa[((fa["rest_type"].str.contains(r'\b'+"Pub"+r'\b'))|(fa["rest_type"].str.contains(r'\b'+"Bar"+r'\b')))&(fa["Discount"]>=40)]
a
# Out:
#                                                     url  \
# 60    https://www.zomato.com/gustoesbeerhouse?contex...
# 100   https://www.zomato.com/bangalore/k27-the-pub-b...
# 325   https://www.zomato.com/bangalore/salut-jayanag...
# 345   https://www.zomato.com/bangalore/eurasia-pasta...
# 384   https://www.zomato.com/bangalore/aadhya-hotel-...
# 660   https://www.zomato.com/bangalore/aadhya-hotel-...
# 725   https://www.zomato.com/bangalore/darbar-banash...
# 919   https://www.zomato.com/bangalore/moksha-kanaka...
# 1043  https://www.zomato.com/bangalore/the-coastal-c...
#
#                                                 address  \
# 60    10/ 30th Main/ Deve Gowda Petrol Bunk Road/ 3r...
# 100   27/ 27th Cross/ 2nd Stage/ Banashankari/ Banga...
# 325   382/71/4/ 11th Main/ 3rd Block/ Jayanagar/ Ban...
# 345     12/ 32nd Cross/ 7th Block/ Jayanagar/ Bangalore
# 384   215/ 2nd Main/ Thygarajanagar/ Basavanagudi/ B...
# 660   215/ 2nd Main/ Thygarajanagar/ Basavanagudi/ B...
# ...

# %%
z=fa[(fa["location"]=="Banashankari")&(fa["approx_cost_for_two_people"]<=800)&(fa["payMode"].str.contains("Paytm"))]
z[["url","address","name","phone"]]
# Out:
#                                                    url  \
# 1    https://www.zomato.com/bangalore/spice-elephan...
# 2    https://www.zomato.com/SanchurroBangalore?cont...
# 7    https://www.zomato.com/bangalore/onesta-banash...
# 8    https://www.zomato.com/bangalore/smacznego-ban...
# 13   https://www.zomato.com/SanchurroBangalore?cont...
# ..                                                 ...
# 642  https://www.zomato.com/bangalore/bitez-banasha...
# 643  https://www.zomato.com/bangalore/bunts-biriyan...
# 721  https://www.zomato.com/gustoesbeerhouse?contex...
# 722  https://www.zomato.com/bangalore/blue-wings-ba...
# 725  https://www.zomato.com/bangalore/darbar-banash...
#
#                                                address  \
# 1    2nd Floor/ 80 Feet Road/ Near Big Bazaar/ 6th ...
# 2    1112/ Next to KIMS Medical College/ 17th Cross...
# 7    2469/ 3rd Floor/ 24th Cross/ Opposite BDA Comp...
# 8    2470/ 21 Main Road/ 25th Cross/ Banashankari/ ...
# ...
