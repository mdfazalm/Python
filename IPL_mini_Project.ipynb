# %% [markdown]
# <a href="https://colab.research.google.com/github/mdfazalm/Python/blob/main/IPL_mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Administrator\Desktop\Python\IPL_Matches_2008-2020.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18-04-2008     BB McCullum
# 1     335983  Chandigarh  19-04-2008      MEK Hussey
# 2     335984       Delhi  19-04-2008     MF Maharoof
# 3     335985      Mumbai  20-04-2008      MV Boucher
# 4     335986     Kolkata  20-04-2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28-09-2020  AB de Villiers
# 812  1237177       Dubai  05-11-2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06-11-2020   KS Williamson
# 814  1237180   Abu Dhabi  08-11-2020      MP Stoinis
# 815  1237181       Dubai  10-11-2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df["city"].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah'], dtype=object)

# %%
df["city"].value_counts()
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
df["city"]=df["city"].fillna("Match Abandoned")

# %%
df.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df["winner"]=df["winner"].fillna("Match Abandoned")

# %%
df["player_of_match"]=df["player_of_match"].fillna("Match Abandoned")

# %%
df["result"]=df["result"].fillna("Match Abandoned")

# %%
re = df[(df["result"] == "runs") & (df["result_margin"]<100)]
re
# Out:
#           id        city        date player_of_match  \
# 1     335983  Chandigarh  19-04-2008      MEK Hussey
# 7     335989     Chennai  23-04-2008       ML Hayden
# 9     335991  Chandigarh  25-04-2008   KC Sangakkara
# 14    335996   Bangalore  28-04-2008        MS Dhoni
# 16    335998       Delhi  30-04-2008      GD McGrath
# ..       ...         ...         ...             ...
# 804  1216540     Sharjah  12-10-2020  AB de Villiers
# 806  1216542       Dubai  08-10-2020     JM Bairstow
# 807  1216543       Dubai  14-10-2020        A Nortje
# 812  1237177       Dubai  05-11-2020       JJ Bumrah
# 814  1237180   Abu Dhabi  08-11-2020      MP Stoinis
#
#                                           venue  neutral_venue  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 7               MA Chidambaram Stadium, Chepauk              0
# 9    Punjab Cricket Association Stadium, Mohali              0
# 14                        M Chinnaswamy Stadium              0
# ...

# %%
x=re["result_margin"].mean()

# %%
df["result_margin"]=df["result_margin"].fillna(x)

# %%
df["eliminator"]=df["eliminator"].fillna("Match Abandoned")

# %%
df["method"]=df["method"].fillna("Match Conducted")

# %%
df.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
a=df["city"].value_counts().head(1)

# %%
df["city"]=df["city"].replace("Bangalore","Bengaluru")

# %%
print(f" the maximum matches were played in {a}")
# Out:
#  the maximum matches were played in city
# Mumbai    101
# Name: count, dtype: int64

# %%
g_df=df[df["city"]!="Bengaluru"]

# %%
g_df
# Out:
#           id        city        date player_of_match  \
# 1     335983  Chandigarh  19-04-2008      MEK Hussey
# 2     335984       Delhi  19-04-2008     MF Maharoof
# 3     335985      Mumbai  20-04-2008      MV Boucher
# 4     335986     Kolkata  20-04-2008       DJ Hussey
# 5     335987      Jaipur  21-04-2008       SR Watson
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28-09-2020  AB de Villiers
# 812  1237177       Dubai  05-11-2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06-11-2020   KS Williamson
# 814  1237180   Abu Dhabi  08-11-2020      MP Stoinis
# 815  1237181       Dubai  10-11-2020        TA Boult
#
#                                           venue  neutral_venue  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
g_df.to_csv(r"C:\Users\Administrator\Desktop\Python\EXB")

# %%
df["date"]=pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# id                          int64
# city                       object
# date               datetime64[ns]
# player_of_match            object
# venue                      object
# neutral_venue               int64
# team1                      object
# team2                      object
# toss_winner                object
# toss_decision              object
# winner                     object
# result                     object
# result_margin             float64
# eliminator                 object
# method                     object
# umpire1                    object
# umpire2                    object
# year                        int32
# dtype: object

# %%
fif=df[df.date.dt.year==2015]
fif
# Out:
#          id           city       date  player_of_match  \
# 458  829705        Kolkata 2015-04-08         M Morkel
# 459  829707        Chennai 2015-04-09          A Nehra
# 460  829709           Pune 2015-04-10      JP Faulkner
# 461  829711        Chennai 2015-04-11      BB McCullum
# 462  829713        Kolkata 2015-04-11         CH Gayle
# 463  829715          Delhi 2015-04-12         DJ Hooda
# 464  829717         Mumbai 2015-04-12        GJ Bailey
# 465  829719      Bengaluru 2015-04-13        DA Warner
# 466  829721      Ahmedabad 2015-04-14        SPD Smith
# 467  829723        Kolkata 2015-04-30       AD Russell
# 468  829725           Pune 2015-04-15       MA Agarwal
# 469  829727  Visakhapatnam 2015-04-16        AM Rahane
# 470  829729         Mumbai 2015-04-17          A Nehra
# 471  829731  Visakhapatnam 2015-04-18        JP Duminy
# 472  829733           Pune 2015-04-18       AD Russell
# 473  829735      Ahmedabad 2015-04-19        AM Rahane
# ...

# %%
fif=df[df["date"].dt.year==2015]
fif
# Out:
#          id           city       date  player_of_match  \
# 458  829705        Kolkata 2015-04-08         M Morkel
# 459  829707        Chennai 2015-04-09          A Nehra
# 460  829709           Pune 2015-04-10      JP Faulkner
# 461  829711        Chennai 2015-04-11      BB McCullum
# 462  829713        Kolkata 2015-04-11         CH Gayle
# 463  829715          Delhi 2015-04-12         DJ Hooda
# 464  829717         Mumbai 2015-04-12        GJ Bailey
# 465  829719      Bengaluru 2015-04-13        DA Warner
# 466  829721      Ahmedabad 2015-04-14        SPD Smith
# 467  829723        Kolkata 2015-04-30       AD Russell
# 468  829725           Pune 2015-04-15       MA Agarwal
# 469  829727  Visakhapatnam 2015-04-16        AM Rahane
# 470  829729         Mumbai 2015-04-17          A Nehra
# 471  829731  Visakhapatnam 2015-04-18        JP Duminy
# 472  829733           Pune 2015-04-18       AD Russell
# 473  829735      Ahmedabad 2015-04-19        AM Rahane
# ...

# %%
b=df["player_of_match"].value_counts().head(1)
b
# Out:
# player_of_match
# AB de Villiers    23
# Name: count, dtype: int64
